# %%
import numpy as np
import sys
import os
import pandas as pd
import random

# Adjust the path to point to external/AlphaPEM
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from src.sampling.sampler import get_polarisation_curve_samples, build_fixed_parameters, sample_parameters, PARAMETER_RANGES

# %%
PARAMETER_RANGES
# Out:
# {'Tfc': (333, 363),
#  'Pa_des': (130000.0, 300000.0),
#  'Pc_des': None,
#  'Sc': (1.1, 3),
#  'Phi_c_des': (0.1, 0.7),
#  'epsilon_gdl': (0.55, 0.8),
#  'tau': (1.0, 4.0),
#  'epsilon_mc': (0.15, 0.4),
#  'epsilon_c': (0.15, 0.3),
#  'e': [3, 4, 5],
#  'Re': (5e-07, 5e-06),
#  'i0_c_ref': (0.001, 500),
#  'kappa_co': (0.01, 40),
#  'kappa_c': (0, 100),
#  'a_slim': (0, 1),
#  'b_slim': (0, 1),
#  'a_switch': (0, 1)}

# %%
parameter_ranges={
  # Operating conditions
  'Tfc': (333, 363),                # Cell temperature (K)
  'Pa_des': (130000.0, 300000.0),   # Desired cell pressure (Pa)
  'Sc': (1.1, 3.0),                 # Stoichiometry anode
  'Phi_c_des': (0.1, 0.7)  ,        # Entrance humidity anode

  # Undetermined physical parameters
  'epsilon_gdl': (0.55, 0.8) ,      # GDL porosity
  'tau': (1.0, 4.0),                # Pore structure coefficient
  'epsilon_mc': (0.15, 0.4) ,       # CL volume fraction of ionomer
  'epsilon_c': (0.15, 0.3),        # GDL compression ratio
  'e': [3, 4, 5] ,                  # Capillary exponent (integer)
  'Re': (5.0e-7, 5.0e-6) ,          # Electron conduction resistance (Ω·m²)
  'i0_c_ref': (0.001, 80),       # Cathode exchange current density (A/m²)
  'kappa_co': (15, 40),        # Crossover correction coefficient (mol/(m·s·Pa))
  'kappa_c': (0, 2.5)  }            # Overpotential correction exponent

# %%
def make_bounds_exclusive(bounds, epsilon=1e-8):
    return [(low + epsilon, high - epsilon) for (low, high) in bounds]

def prepare_problem(PARAMETER_RANGES):
    independent_params = {k: v for k, v in PARAMETER_RANGES.items()}
    # Add dummy variable to later compute dependent_param
    
    bounds = [v if isinstance(v, tuple) else [min(v), max(v)] for v in independent_params.values()]
    bounds = make_bounds_exclusive(bounds)

    problem = {
        "num_vars": len(independent_params),
        "names": list(independent_params.keys()),
        "bounds": bounds,
        "groups": list(independent_params.keys())  # optional but useful for group-based SA
    }
    return problem

problem = prepare_problem(parameter_ranges)

# %%
problem
# Out:
# {'num_vars': 13,
#  'names': ['Tfc',
#   'Pa_des',
#   'Sc',
#   'Phi_c_des',
#   'epsilon_gdl',
#   'tau',
#   'epsilon_mc',
#   'epsilon_c',
#   'e',
#   'Re',
#   'i0_c_ref',
#   'kappa_co',
#   'kappa_c'],
#  'bounds': [(333.00000001, 362.99999999),
#   (130000.00000001, 299999.99999999),
#   (1.10000001, 2.99999999),
#   (0.10000001, 0.6999999899999999),
#   (0.5500000100000001, 0.79999999),
#   (1.00000001, 3.99999999),
#   (0.15000001, 0.39999999),
#   (0.15000001, 0.29999999),
#   (3.00000001, 4.99999999),
#   (5.1e-07, 4.9900000000000005e-06),
#   (0.00100001, 79.99999999),
#   (15.00000001, 39.99999999),
#   (1e-08, 2.49999999)],
#  'groups': ['Tfc',
#   'Pa_des',
#   'Sc',
#   'Phi_c_des',
#   'epsilon_gdl',
#   'tau',
#   'epsilon_mc',
#   'epsilon_c',
#   'e',
#   'Re',
#   'i0_c_ref',
#   'kappa_co',
#   'kappa_c']}

# %%
from SALib.sample import sobol
from SALib.analyze import sobol as sobol_analyze
import random

def generate_samples(problem, N=2, seed=42):
    np.random.seed(seed)
    random.seed(seed)
    samples = sobol.sample(problem, N=N, calc_second_order= True, scramble= True, seed=seed)

    # Add a new column for the trajectory number
    trajectory_numbers = np.tile(np.arange(1, N + 1), (problem["num_vars"], 1)).flatten()

    return pd.DataFrame(samples, columns=problem["names"]), trajectory_numbers

def compute_dependent_param(df_samples, param_name="Pc_des", Pext=101325):
    z_key = f"z_{param_name}"
    Pa_des = df_samples["Pa_des"]
    z = df_samples[z_key]

    low = np.maximum(Pext, Pa_des - 0.5e5)
    high = np.maximum(Pext, Pa_des - 0.1e5)

    df_samples[param_name] = low + z * (high - low)
    df_samples = df_samples.drop(columns=z_key)
    return df_samples, low, high

df_samples, trajectory_numbers = generate_samples(problem, N=64)
df_samples, low, high = compute_dependent_param(df_samples)
print(df_samples.shape)

df_samples['e'] = np.round(df_samples['e'])
# Out:
# (2560, 19)

# %%
import pickle

#with open('../data/raw/df_samples_sobol_N64_S2.pkl', 'wb') as file:
#    pickle.dump(df_samples, file)

with open('../data/raw/df_samples_sobol_N64_S2.pkl', "rb") as f:
    df_samples = pickle.load(f)

# %%
def is_sample_in_bounds(sample, bounds_dict):
    """
    Check if a sample is within the specified parameter bounds.

    Args:
        sample (dict): A dictionary of parameter values.
        bounds_dict (dict): A dictionary with parameter names as keys and tuples or lists as bounds.

    Returns:
        bool: True if all parameters are within bounds, False otherwise.
        dict: A dictionary of out-of-bound parameters with their values and bounds.
    """
    out_of_bounds = {}

    for key, bounds in bounds_dict.items():
        if key not in sample:
            continue  # skip if not part of the sample

        value = sample[key]

        if bounds is None:
            continue  # no bounds specified

        if isinstance(bounds, tuple):
            lower, upper = bounds
            if not (lower <= value <= upper):
                out_of_bounds[key] = {"value": value, "bounds": bounds}

        elif isinstance(bounds, list):
            if value not in bounds:
                out_of_bounds[key] = {"value": value, "allowed": bounds}

    return len(out_of_bounds) == 0, out_of_bounds

for sample in df_samples.to_dict(orient='records'):
    res = is_sample_in_bounds(sample, bounds_dict=PARAMETER_RANGES)
    if res[0] == False:
        print(res[1])

# %%
#results = get_polarisation_curve_samples(df_samples.to_dict(orient='records'), fixed_parameters = build_fixed_parameters(), save_path='../data/raw/sobol_sample_results_N64.pkl')
# Out:
# ✅ Saved 10 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 20 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 30 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 40 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 50 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 60 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 70 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 80 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 90 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 100 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 110 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 120 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 130 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 140 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 150 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 160 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 170 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 180 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 190 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 200 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 210 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 220 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 230 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 240 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 250 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 260 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 270 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 280 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 290 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 300 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 310 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 320 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 330 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 340 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 350 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 360 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 370 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 380 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 390 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 400 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 410 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 420 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 430 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 440 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 450 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 460 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 470 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 480 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 490 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 500 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 510 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 520 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 530 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 540 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 550 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 560 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 570 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 580 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 590 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 600 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 610 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 620 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 630 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 640 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 650 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 660 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 670 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 680 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 690 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 700 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 710 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 720 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 730 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 740 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 750 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 760 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 770 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 780 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 790 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 800 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 810 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 820 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 830 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 840 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 850 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 860 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 870 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 880 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 890 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 900 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 910 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 920 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 930 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 940 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 950 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 960 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 970 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 980 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 990 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1000 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1010 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1020 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1030 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1040 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1050 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1060 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1070 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1080 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1090 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1100 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1110 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1120 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1130 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1140 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1150 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1160 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1170 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1180 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1190 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1200 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1210 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1220 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1230 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1240 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1250 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1260 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1270 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1280 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1290 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1300 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1310 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1320 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1330 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1340 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1350 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1360 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1370 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1380 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1390 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1400 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1410 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1420 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1430 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1440 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1450 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1460 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1470 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1480 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1490 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1500 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1510 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1520 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1530 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1540 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1550 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1560 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1570 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1580 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1590 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1600 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1610 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1620 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1630 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1640 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1650 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1660 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1670 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1680 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1690 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1700 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1710 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1720 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1730 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1740 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1750 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1760 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1770 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1780 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1790 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1800 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1810 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1820 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1830 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1840 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1850 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1860 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1870 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1880 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1890 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1900 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1910 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1920 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1930 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1940 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1950 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1960 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1970 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1980 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 1990 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2000 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2010 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2020 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2030 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2040 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2050 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2060 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2070 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2080 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2090 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2100 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2110 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2120 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2130 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2140 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2150 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2160 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2170 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2180 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2190 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2200 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2210 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2220 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2230 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2240 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2250 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2260 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2270 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2280 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2290 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2300 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2310 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2320 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2330 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2340 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2350 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2360 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2370 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2380 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2390 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2400 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2410 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2420 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2430 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2440 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2450 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2460 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2470 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2480 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2490 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2500 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2510 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2520 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2530 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2540 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2550 samples to ../data/raw/sobol_sample_results_N64.pkl
# ✅ Saved 2560 samples to ../data/raw/sobol_sample_results_N64.pkl
#
# 📁 Final save complete: ../data/raw/sobol_sample_results_N64.pkl with 2560 valid samples.

# %%
results = pd.read_pickle('../data/raw/lhs_500.pkl')

# %%
def replace_z_with_actual_param(problem, low, high, param_name="Pc_des"):
    z_key = f"z_{param_name}"
    idx = problem["names"].index(z_key)
    problem["names"][idx] = param_name
    problem["bounds"][idx] = (low.min(), high.max())
    problem["groups"][idx] = param_name
    return problem

problem = replace_z_with_actual_param(problem, low, high)

# %%
## We keep the configurations that have a valid Ucell
none_list =[]
for i, cell in enumerate(results['Ucell']):
    if cell is None:
        none_list.append(i)
        
results = results.drop(none_list, axis=0).reset_index(drop=True)

# %%
results.shape
# Out:
# (499, 48)

# %% [markdown]
# **Number of samples**
#
# * If calc_second_order=False:  N * (D + 2)
# * If calc_second_order=True:  N * (2D + 2)

# %%
## From the sample we have, we calculate how many samples is an appropiate nomber to use Sobol analysis
def get_correct_sample_size_sobol(problem,df, order=1,seed=33):
    """
    Calculate and filter the DF with the number of samples needed for Sobol analysis based on the problem size and order.
    
    Args:
        problem (dict): The problem definition containing 'num_vars'.
        df (dataframe): The DataFrame containing the results.
        order (int): The order of Sobol indices (1 for first order, 2 for second order).
        seed (int): Random seed for reproducibility.
        
    Returns:
        dataframe: Filtered dataframe of the correct size.
    """
    num_vars = problem["num_vars"]
    if order not in [1, 2]:
        raise ValueError("Order must be either 1 or 2.")
    if order == 1:
        sample_size = int(np.floor(len(results)/(problem["num_vars"]+2))*(problem["num_vars"]+2))
    elif order == 2:
        sample_size = int(np.floor(len(results)/((2*problem["num_vars"])+2))*((2*problem["num_vars"])+2))

    
    return df.sample(n=sample_size, random_state=seed)

## Sample df for first order Sobol index
results_sampled = get_correct_sample_size_sobol(problem,df = results,order=1)

## Sample df for first & second order Sobol index
results_sampled_2order = get_correct_sample_size_sobol(problem,df = results,order=2)

# %%
print(f"Number of samples: {results.shape}, {results_sampled.shape}, {results_sampled_2order.shape}")
# Out:
# Number of samples: (499, 48), (495, 48), (476, 48)

# %%
from SALib.sample import sobol
from SALib.analyze import sobol as sobol_analyze
def run_sobol_analysis( problem, results, output_key='Ucell', num_resamples = 100,seed=42,second_order=False):
    np.random.seed(seed)
    random.seed(seed)

    Y_all = np.stack(results[output_key].values)
    n_outputs = Y_all.shape[1]

    sobol_all = []
    for i in range(n_outputs):
        analysis = sobol_analyze.analyze(
            problem=problem,
            Y=Y_all[:, i],
            calc_second_order = second_order,
            num_resamples=num_resamples,
            conf_level=0.95,
            print_to_console=False,
            seed = 42
        )
        if second_order:
            sobol_all.append({
                'S1': analysis['S1'],
                'S1_conf': analysis['S1_conf'],
                'S2': analysis['S2'],
                'S2_conf': analysis['S2_conf'],
                'ST': analysis['ST'],
                'ST_conf': analysis['ST_conf'],
                'param': problem['names'],
                'output_index': i
            })
        else:
            sobol_all.append({
                'S1': analysis['S1'],
                'S1_conf': analysis['S1_conf'],
                'ST': analysis['ST'],
                'ST_conf': analysis['ST_conf'],
                'param': problem['names'],
                'output_index': i
            })
    return sobol_all

sobol_all = run_sobol_analysis( problem, results_sampled,num_resamples = 1000,second_order=False)
# Out:
# d:\Users\kju10\Documents\LMU-STATISTICS & DATA SCIENCE MASTER\WS2425\Consulting\project\Sensitivity-Analysis-and-Surrogate-Modeling-of-PEM-Fuel-Cells\env\Lib\site-packages\SALib\util\__init__.py:274: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   names = list(pd.unique(groups))

# %%
sobol_all_2 = run_sobol_analysis( problem, results_sampled_2order,num_resamples = 1000,second_order=True)
# Out:
# d:\Users\kju10\Documents\LMU-STATISTICS & DATA SCIENCE MASTER\WS2425\Consulting\project\Sensitivity-Analysis-and-Surrogate-Modeling-of-PEM-Fuel-Cells\env\Lib\site-packages\SALib\util\__init__.py:274: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   names = list(pd.unique(groups))

# %%
type(sobol_all)
# Out:
# list

# %%
sobol_all[0]['param']
# Out:
# ['Tfc',
#  'Pa_des',
#  'Sc',
#  'Phi_c_des',
#  'epsilon_gdl',
#  'tau',
#  'epsilon_mc',
#  'epsilon_c',
#  'e',
#  'Re',
#  'i0_c_ref',
#  'kappa_co',
#  'kappa_c']

# %%
sobol_all[0].keys()
# Out:
# dict_keys(['S1', 'S1_conf', 'ST', 'ST_conf', 'param', 'output_index'])

# %%
df_long = pd.DataFrame({'param': sobol_all[0]['param']})
for i, res in enumerate(sobol_all):
    df_long[f'S1_{i}'] = res['S1']

df_long_rank = pd.DataFrame({'param': sobol_all[0]['param']})
for col in df_long.columns:
    rank_col = f'{col}_rank'
    df_long_rank[rank_col] = df_long[col].rank(method='min', ascending=False).astype(int) 


with pd.ExcelWriter('../data/raw/sobol_sensitivity_analysis_lhs_500.xlsx', engine='xlsxwriter') as writer:
    df_long.to_excel(writer, sheet_name='S1_values', index=False)
    df_long_rank.to_excel(writer, sheet_name='S1_ranks', index=False)

# %%
sobol_all_2[0]['S2']
# Out:
# array([[            nan,  1.39730960e-01,  5.63394263e-02,
#          4.95332807e-01,  3.81643853e-01,  5.42419404e-01,
#          2.85629162e-01,  5.60281289e-01,  9.18123531e-01,
#          1.24213853e-01, -1.72561724e-01,  1.07205190e-01,
#          1.70596257e+00],
#        [            nan,             nan, -7.01326596e-02,
#         -1.37687102e-01,  2.65734598e-01,  5.45967499e-01,
#          3.61970378e-01,  7.54920102e-01,  2.39157436e-01,
#          6.21070790e-01,  6.87649520e-01,  1.11039945e+00,
#          1.75781472e+00],
#        [            nan,             nan,             nan,
#         -2.21007790e-01, -3.61698125e-01,  4.11101965e-02,
#         -2.28694750e-01,  2.97286741e-01,  1.00998947e-01,
#         -3.91733519e-01, -3.94464410e-01, -3.23384957e-03,
#          7.50332975e-01],
#        [            nan,             nan,             nan,
#                     nan, -6.61349616e-01, -3.02670566e-01,
#         -5.30130189e-01, -3.33827979e-02, -4.38006210e-01,
#         -5.89535798e-01, -5.73803017e-01,  7.70953406e-02,
#          1.90162542e-01],
#        [            nan,             nan,             nan,
#                     nan,             nan, -5.28219444e-01,
#         -1.83951822e-01, -3.35004414e-02,  2.33394439e-01,
#         -3.11036908e-01,  1.32324021e-01, -4.01371095e-03,
#          9.18333540e-01],
#        [            nan,             nan,             nan,
#                     nan,             nan,             nan,
#          2.54297520e-01,  4.39551510e-02,  3.39629802e-01,
#          4.26773183e-01,  2.03017331e-01,  5.24548364e-01,
#          1.61903305e+00],
#        [            nan,             nan,             nan,
#                     nan,             nan,             nan,
#                     nan,  7.01733477e-02, -1.03273460e-01,
#         -2.09330453e-02, -1.67725825e-02,  1.00780630e-01,
#          5.61522841e-01],
#        [            nan,             nan,             nan,
#                     nan,             nan,             nan,
#                     nan,             nan,  3.40713872e-01,
#         -7.94092572e-02,  6.36736509e-01,  5.47506318e-01,
#          1.49297971e+00],
#        [            nan,             nan,             nan,
#                     nan,             nan,             nan,
#                     nan,             nan,             nan,
#          2.38988920e-01,  3.72984025e-01,  8.47177542e-01,
#          8.03466093e-01],
#        [            nan,             nan,             nan,
#                     nan,             nan,             nan,
#                     nan,             nan,             nan,
#                     nan, -7.55048900e-04,  4.07870535e-01,
#          1.02567011e+00],
#        [            nan,             nan,             nan,
#                     nan,             nan,             nan,
#                     nan,             nan,             nan,
#                     nan,             nan,  6.61415036e-01,
#          1.01949807e+00],
#        [            nan,             nan,             nan,
#                     nan,             nan,             nan,
#                     nan,             nan,             nan,
#                     nan,             nan,             nan,
#          1.78462991e+00],
#        [            nan,             nan,             nan,
#                     nan,             nan,             nan,
#                     nan,             nan,             nan,
#                     nan,             nan,             nan,
#                     nan]])

# %%
import pandas as pd
import itertools

# Assuming sobol_all_2 is your list of results
params = sobol_all_2[0]['param']  # param names
pairs = list(itertools.product(params, params))  # all (param_1, param_2) combinations

# Initialize DataFrame with param pairs
df_s2_all = pd.DataFrame(pairs, columns=['param_1', 'param_2'])

# Add one column per S2 matrix
for i, res in enumerate(sobol_all_2):
    s2_matrix = res['S2']
    
    # Flatten S2 matrix row-wise and add as a column
    flat_s2 = [s2_matrix[r][c] for r in range(len(params)) for c in range(len(params))]
    df_s2_all[f'S2_{i}'] = flat_s2

# %%
df_s2_all_ = df_s2_all.dropna(how='all', subset=df_s2_all.columns[2:])

# %%
import itertools

# Create DataFrame with param pairs and proper column names
df_s2_all_long_rank = pd.DataFrame(itertools.product(params, params), columns=['param_1', 'param_2'])

# Loop over S2 columns (e.g., S2_0, S2_1, ...) from df_s2_all and create rank columns in df_s2_all_long_rank
for col in df_s2_all.columns[2:]:  # skip param_1, param_2
    rank_col = f'{col}_rank'
    df_s2_all_long_rank[rank_col] = df_s2_all[col].rank(method='min', ascending=False)#.astype(int)

df_s2_all_long_rank_ = df_s2_all_long_rank.dropna(how='all', subset=df_s2_all_long_rank.columns[2:])

with pd.ExcelWriter('../data/raw/sobol_sensitivity_analysis_lhs_500_1_2_order.xlsx', engine='xlsxwriter') as writer:
    df_s2_all_.to_excel(writer, sheet_name='S1_S2_values', index=False)
    df_s2_all_long_rank_.to_excel(writer, sheet_name='S1_S2_ranks', index=False)

# %%
import matplotlib.pyplot as plt
import math

def plot_sobol_sensitivity_entire_function(sobol_all, problem, n_cols=3):
    """
    Plots the sensitivity of parameters based on sobol_all results in subplots.
    
    Parameters:
        sobol_all (list of dict): List containing the sensitivity analysis results.
        problem (dict): Dictionary containing problem information, including parameter names.
        n_cols (int): Number of columns in the subplot grid (default is 3).
    """
    params = problem['names']
    n_params = len(params)
    n_outputs = len(sobol_all)

    # Calculate the number of rows needed based on number of columns
    n_rows = math.ceil(n_params / n_cols)

    # Create subplots with the calculated number of rows and columns
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(8 * n_cols, 4 * n_rows))

    # Flatten axes array for easier iteration
    axes = axes.flatten()

    # Loop through each parameter and create a plot in the corresponding subplot
    for param_idx, ax in enumerate(axes):
        if param_idx >= n_params:
            ax.axis('off')  # Hide empty subplots if there are fewer parameters than subplots
            continue

        S1_vals = []
        S1_conf_vals = []
        ST_vals = []
        ST_conf_vals = []
        output_indices = []

        for output in sobol_all:
            S1_vals.append(output['S1'][param_idx])
            S1_conf_vals.append(output['S1_conf'][param_idx])
            ST_vals.append(output['ST'][param_idx])
            ST_conf_vals.append(output['ST_conf'][param_idx])
            output_indices.append(output['output_index'])

        S1_vals = np.array(S1_vals)
        S1_conf_vals = np.array(S1_conf_vals)
        ST_vals = np.array(ST_vals)
        ST_conf_vals = np.array(ST_conf_vals)
        output_indices = np.array(output_indices)

        
        ax.plot(output_indices, S1_vals, marker='o', color='blue')
        ax.plot(output_indices, ST_vals, marker='o', color='red')

        # Add confidence bands
        ax.fill_between(output_indices, S1_vals - S1_conf_vals, S1_vals + S1_conf_vals, color='blue', alpha=0.2)
        ax.fill_between(output_indices, ST_vals - ST_conf_vals, ST_vals + ST_conf_vals, color='red', alpha=0.2)
        
        
        ax.set_xlabel(r'Output', fontsize=12)
        ax.set_ylabel(r'Sobol sensitivity Indices', fontsize=12)
        ax.set_title(f'Sensitivity of Parameter: {params[param_idx]}', fontsize=14)
        ax.grid(True)
        ax.legend()

    handles = [plt.Line2D([0], [0], color='blue', label='S1'), plt.Line2D([0], [0], color='red', label='ST')]
    fig.legend(handles=handles, bbox_to_anchor=(0.5, 1.02), loc='upper center', ncol=2)
    plt.subplots_adjust(top=0.92)
    # Adjust layout and add extra vertical space
    plt.subplots_adjust(hspace=0.4)  # Adjust this value to control the vertical space
    plt.tight_layout()
    plt.show()

plot_sobol_sensitivity_entire_function(sobol_all, problem)
# Out:
# C:\Users\Camila Bermudez\AppData\Local\Temp\ipykernel_12756\3766127246.py:64: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns  # For nicer heatmaps

def plot_sobol_S2_heatmap(sobol_result, problem):
    """
    Plots the S2 (second-order Sobol indices) as a heatmap.
    
    Parameters:
        sobol_result (dict): Single output's Sobol sensitivity analysis result.
        problem (dict): Dictionary containing problem information, including parameter names.
    """
    param_names = problem['names']
    n_params = len(param_names)
    
    # Extract S2 matrix
    S2_matrix = np.zeros((n_params, n_params))

    for i in range(n_params):
        for j in range(n_params):
            if i == j:
                S2_matrix[i, j] = np.nan  # You can decide to put NaN or 0 on the diagonal (no self-interaction)
            else:
                S2_matrix[i, j] = sobol_result['S2'][i][j]

    # Plot heatmap
    plt.figure(figsize=(10, 8))
    sns.heatmap(S2_matrix, 
                xticklabels=param_names, 
                yticklabels=param_names, 
                cmap="coolwarm", 
                annot=True, 
                fmt=".2f", 
                mask=np.isnan(S2_matrix),
                cbar_kws={'label': 'Second-order sensitivity (S2)'})
    
    plt.title('Second-Order Sobol Sensitivity (S2) Heatmap', fontsize=16)
    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()

# Example call (assuming you have sobol_all and problem already defined):
#plot_sobol_S2_heatmap(sobol_all[0], problem)
plot_sobol_S2_heatmap(sobol_all_2[0], problem)

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_sobol_sensitivity_per_index(sobol_all, figsize=(10, 6), sort_by='S1'):
    """
    Plots Sobol sensitivity analysis results with side-by-side horizontal bar plots for S1 and ST.
    
    Parameters:
    - sobol_all: list of dicts with keys 'S1', 'S1_conf', 'ST', 'ST_conf', 'param', and 'output_index'
    - figsize: tuple, size of each plot
    - sort_by: 'S1' or 'ST', which index to use for sorting bars (default is 'S1')
    """
    n_outputs = len(sobol_all)

    for i in range(n_outputs):
        result = sobol_all[i]
        S1 = np.array(result['S1'])
        S1_conf = np.array(result['S1_conf'])
        ST = np.array(result['ST'])
        ST_conf = np.array(result['ST_conf'])
        param_names = np.array(result['param'])

        # Choose sorting
        if sort_by == 'S1':
            sort_idx = np.argsort(-S1)  # Descending
        else:
            sort_idx = np.argsort(-ST)

        # Apply sorting
        S1 = S1[sort_idx]
        S1_conf = S1_conf[sort_idx]
        ST = ST[sort_idx]
        ST_conf = ST_conf[sort_idx]
        param_names = param_names[sort_idx]

        # Positions for side-by-side bars
        y = np.arange(len(param_names))
        offset = 0.2

        fig, ax = plt.subplots(figsize=figsize)

        ax.barh(y - offset, S1, xerr=S1_conf, height=0.35, label='S1', color='blue', capsize=4)
        ax.barh(y + offset, ST, xerr=ST_conf, height=0.35, label='ST', color='red', capsize=4)

        ax.set_yticks(y)
        ax.set_yticklabels(param_names)
        ax.set_xlabel('Sobol Indices')
        ax.set_title(f'Sobol Sensitivity - Output Index {i}')
        ax.invert_yaxis()  # Highest value at the top
        ax.grid(axis='x', linestyle='--', alpha=0.7)
        ax.legend()
        plt.tight_layout()
        plt.show()
plot_sobol_sensitivity_per_index(sobol_all)
